# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
data = pd.read_excel('/content/DS - Assignment Part 1 data set.xlsx')

# %%
data.head(10)
# Out:
#    Transaction_date  House_Age  Distance_from_nearest_Metro_station  \
# 0       2012.916667       32.0                             84.87882
# 1       2012.916667       19.5                            306.59470
# 2       2013.583333       13.3                            561.98450
# 3       2013.500000       13.3                            561.98450
# 4       2012.833333        5.0                            390.56840
# 5       2012.666667        7.1                           2175.03000
# 6       2012.666667       34.5                            623.47310
# 7       2013.416667       20.3                            287.60250
# 8       2013.500000       31.7                           5512.03800
# 9       2013.416667       17.9                           1783.18000
#
#    Number_of_convenience_stores  latitude  longitude  bedrooms  \
# 0                            10  24.98298  121.54024         1
# 1                             9  24.98034  121.53951         2
# ...

# %%
data.describe()
# Out:
#        Transaction_date   House_Age  Distance_from_nearest_Metro_station  \
# count        414.000000  414.000000                           414.000000
# mean        2013.148953   17.712560                          1083.885689
# std            0.281995   11.392485                          1262.109595
# min         2012.666667    0.000000                            23.382840
# 25%         2012.916667    9.025000                           289.324800
# 50%         2013.166667   16.100000                           492.231300
# 75%         2013.416667   28.150000                          1454.279000
# max         2013.583333   43.800000                          6488.021000
#
#        Number_of_convenience_stores    latitude   longitude    bedrooms  \
# count                    414.000000  414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361    1.987923
# std                        2.945562    0.012410    0.015347    0.818875
# ...

# %%
data['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=data.latitude.values, y=data.longitude.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
plt1 = plt()
sns.despine
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-f92bdd68b851> in <module>
#       4 plt.xlabel('Latitude', fontsize=12)
#       5 plt.show()
# ----> 6 plt1 = plt()
#       7 sns.despine
#
# TypeError: 'module' object is not callable

# %%
plt.scatter(data.House_price_of_unit_area, data.House_size_sqft)
plt.title("Price vs Square Feet")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %%
plt.scatter(data.House_price_of_unit_area,data.longitude)
plt.title("Price vs Location of the area")
# Out:
# Text(0.5, 1.0, 'Price vs Location of the area')

# %%
plt.scatter(data.House_price_of_unit_area,data.latitude)
plt.xlabel("Price")
plt.ylabel('Latitude')
plt.title("Latitude vs Price")
# Out:
# Text(0.5, 1.0, 'Latitude vs Price')

# %%
plt.scatter(data.bedrooms,data.House_price_of_unit_area)
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter((data['House_size_sqft']+data['Number_of_convenience_stores']),data['House_price_of_unit_area'])

# %%
plt.scatter(data.House_Age,data.House_price_of_unit_area)
plt.title("House Age vs Price")
# Out:
# Text(0.5, 1.0, 'House Age vs Price')

# %%
plt.scatter(data.House_price_of_unit_area, data.Distance_from_nearest_Metro_station)
plt.title("Price vs Nearest to Metro")
# Out:
# Text(0.5, 1.0, 'Price vs Nearest to Metro')

# %%
train1 = data.drop(['Transaction_date', 'House_price_of_unit_area'],axis=1)

# %%
train1.head()
# Out:
#    House_Age  Distance_from_nearest_Metro_station  \
# 0       32.0                             84.87882
# 1       19.5                            306.59470
# 2       13.3                            561.98450
# 3       13.3                            561.98450
# 4        5.0                            390.56840
#
#    Number_of_convenience_stores  latitude  longitude  bedrooms  \
# 0                            10  24.98298  121.54024         1
# 1                             9  24.98034  121.53951         2
# 2                             5  24.98746  121.54391         3
# 3                             5  24.98746  121.54391         2
# 4                             5  24.97937  121.54245         1
#
#    House_size_sqft
# 0              575
# 1             1240
# 2             1060
# 3              875
# 4              491

# %%
data.House_Age.value_counts().plot(kind='bar')

# %%
plt.scatter(data.House_Age,data.House_price_of_unit_area)

# %%
plt.scatter(data.Number_of_convenience_stores,data.House_price_of_unit_area)

# %%
plt.scatter(data.Distance_from_nearest_Metro_station,data.House_price_of_unit_area)
plt.title("Which is the pricey location by Distancef from nearest Metro station?")
# Out:
# Text(0.5, 1.0, 'Which is the pricey location by Distancef from nearest Metro station?')

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
labels = data['House_price_of_unit_area']
conv_dates = [1 if values == 2013 else 0 for values in data.Transaction_date ]
data['date'] = conv_dates
train1 = data.drop(['House_price_of_unit_area'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(train1 , labels , test_size = 0.10,random_state =2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# 0.6608161565412554

# %%
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'ls')

# %%
clf.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:290: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   FutureWarning,
# GradientBoostingRegressor(loss='ls', max_depth=5, n_estimators=400)

# %%
clf.score(x_test,y_test)
# Out:
# 0.8450237023813244

# %%
t_sc = np.zeros((params['n_estimators']),dtype=np.float64)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-d628749a6478> in <module>
# ----> 1 t_sc = np.zeros((clf['n_estimators']),dtype=np.float64)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_base.py in __getitem__(self, index)
#     182     def __getitem__(self, index):
#     183         """Return the index'th estimator in the ensemble."""
# --> 184         return self.estimators_[index]
#     185
#     186     def __iter__(self):
#
# AttributeError: 'GradientBoostingRegressor' object has no attribute 'estimators_'

# %%
y_pred = reg.predict(x_test)

# %%
for i,y_pred in enumerate(clf.staged_predict(x_test)):
    t_sc[i]=clf.loss_(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-48d2521719a6> in <module>
#       1 for i,y_pred in enumerate(clf.staged_predict(x_test)):
# ----> 2     t_sc[i]=clf.loss_(y_test,y_pred)
#
# NameError: name 't_sc' is not defined

# %%
testsc = np.arange((params['n_estimators']))+1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-0937e0982976> in <module>
# ----> 1 testsc = np.arange((params['n_estimators']))+1
#
# NameError: name 'params' is not defined

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(testsc,clf.train_score_,'b-',label= 'Set dev train')
plt.plot(testsc,t_sc,'r-',label = 'set dev test')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-fb74cab3dbff> in <module>
#       1 plt.figure(figsize=(12, 6))
#       2 plt.subplot(1, 2, 1)
# ----> 3 plt.plot(testsc,clf.train_score_,'b-',label= 'Set dev train')
#       4 plt.plot(testsc,t_sc,'r-',label = 'set dev test')
#
# NameError: name 'testsc' is not defined

# %%
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
pca.fit_transform(scale(train1))
# Out:
# array([[-1.9591568 ,  1.88804353, -0.4962995 , ..., -0.79252761,
#         -0.1888713 ,  0.17964821],
#        [-1.81457899, -0.34215184,  0.34856387, ..., -0.68618775,
#         -0.62216129,  0.1309621 ],
#        [-1.54273361, -1.23992847, -0.86613024, ...,  0.77474341,
#          0.57645611,  0.38658638],
#        ...,
#        [-1.18889419,  1.71050402, -0.84793859, ..., -0.22210254,
#          0.00717454,  0.12902688],
#        [-0.07184374,  2.28402578,  2.68545606, ..., -0.04459946,
#         -0.15745854, -0.53960984],
#        [-1.77248754, -0.41687967, -0.54001043, ..., -0.95998346,
#         -0.26928816,  0.00768055]])
